# %% [markdown]
# # Data Cleaning & Missing Value Handling

# %% [markdown]
# ## Step 1: Load Datasets

# %%
import pandas as pd
housing = pd.read_csv('Housing.csv')
medical = pd.read_csv('Medical Appointment.csv')

# %% [markdown]
# ## Step 2: Identify Missing Values

# %%
housing.isnull().sum()
medical.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %% [markdown]
# ## Step 3: Handle Missing Values

# %% [markdown]
# - Numerical: Median Imputation
# - Categorical: Mode Imputation
# - Drop columns with >40% missing

# %% [markdown]
# ## Step 4: Validate Cleaned Data

# %%
housing.shape
medical.shape
# Out:
# (110527, 14)
